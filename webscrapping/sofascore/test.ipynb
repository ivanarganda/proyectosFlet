# %%
import polars as pl
import pandas as pd

pd.set_option('display.max_rows', None)        # Muestra todas las filas
pd.set_option('display.max_columns', None)     # Muestra todas las columnas
pd.set_option('display.max_colwidth', None)    # No corta texto en columnas
pd.set_option('display.width', None)           # Sin límite de ancho en pantalla
pd.set_option('display.expand_frame_repr', True)

df = pl.read_excel("Server/files_initted/jugadores_stats_info_db.xlsx")

df = df.to_pandas()

print( df.isna().sum().to_frame("nulls") )
# Out:
# Could not determine dtype for column 47, falling back to string
# Could not determine dtype for column 70, falling back to string
# Could not determine dtype for column 71, falling back to string
# Could not determine dtype for column 72, falling back to string
# Could not determine dtype for column 81, falling back to string
#                               nulls
# id_estadistica_jugadores          0
# id_jugador                        0
# id_equipo                         0
# id_partido                        0
# id_jornada                        0
# substitute                        0
# captain                        5961
# teamName                          0
# country_alpha2                    0
# country_alpha3                    0
# country_name                      0
# country_slug                      0
# position                          0
# minutesPlayed                  1826
# rating                         1889
# ratingVersions                 1889
# ...

# %%
print( df.shape[0] )
# Out:
# 6241
